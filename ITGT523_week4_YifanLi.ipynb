# %%
# %cd /content/drive/MyDrive/dataset
# Out:
# /content/drive/MyDrive/dataset

# %%
# !unzip GeorgiaTech.zip
# Out:
# Archive:  GeorgiaTech.zip
#    creating: gt_db_train/
#    creating: gt_db_train/s01/
#   inflating: gt_db_train/s01/01.jpg
#   inflating: gt_db_train/s01/02.jpg
#   inflating: gt_db_train/s01/03.jpg
#   inflating: gt_db_train/s01/04.jpg
#   inflating: gt_db_train/s01/05.jpg
#   inflating: gt_db_train/s01/06.jpg
#   inflating: gt_db_train/s01/07.jpg
#   inflating: gt_db_train/s01/08.jpg
#   inflating: gt_db_train/s01/09.jpg
#   inflating: gt_db_train/s01/10.jpg
#    creating: gt_db_train/s02/
#   inflating: gt_db_train/s02/01.jpg
#   inflating: gt_db_train/s02/02.jpg
#   inflating: gt_db_train/s02/03.jpg
#   inflating: gt_db_train/s02/04.jpg
#   inflating: gt_db_train/s02/05.jpg
#   inflating: gt_db_train/s02/06.jpg
#   inflating: gt_db_train/s02/07.jpg
#   inflating: gt_db_train/s02/08.jpg
#   inflating: gt_db_train/s02/09.jpg
#   inflating: gt_db_train/s02/10.jpg
#    creating: gt_db_train/s03/
#   inflating: gt_db_train/s03/01.jpg
#   inflating: gt_db_train/s03/02.jpg
#   inflating: gt_db_train/s03/03.jpg
#   inflating: gt_db_train/s03/04.jpg
#   inflating: gt_db_train/s03/05.jpg
#   inflating: gt_db_train/s03/06.jpg
#   inflating: gt_db_train/s03/07.jpg
#   inflating: gt_db_train/s03/08.jpg
#   inflating: gt_db_train/s03/09.jpg
#   inflating: gt_db_train/s03/10.jpg
#    creating: gt_db_train/s04/
#   inflating: gt_db_train/s04/01.jpg
#   inflating: gt_db_train/s04/02.jpg
#   inflating: gt_db_train/s04/03.jpg
#   inflating: gt_db_train/s04/04.jpg
#   inflating: gt_db_train/s04/05.jpg
#   inflating: gt_db_train/s04/06.jpg
#   inflating: gt_db_train/s04/07.jpg
#   inflating: gt_db_train/s04/08.jpg
#   inflating: gt_db_train/s04/09.jpg
#   inflating: gt_db_train/s04/10.jpg
#    creating: gt_db_train/s05/
#   inflating: gt_db_train/s05/01.jpg
#   inflating: gt_db_train/s05/02.jpg
#   inflating: gt_db_train/s05/03.jpg
#   inflating: gt_db_train/s05/04.jpg
#   inflating: gt_db_train/s05/05.jpg
#   inflating: gt_db_train/s05/06.jpg
#   inflating: gt_db_train/s05/07.jpg
#   inflating: gt_db_train/s05/08.jpg
#   inflating: gt_db_train/s05/09.jpg
#   inflating: gt_db_train/s05/10.jpg
#    creating: gt_db_train/s06/
#   inflating: gt_db_train/s06/01.jpg
#   inflating: gt_db_train/s06/02.jpg
#   inflating: gt_db_train/s06/03.jpg
#   inflating: gt_db_train/s06/04.jpg
#   inflating: gt_db_train/s06/05.jpg
#   inflating: gt_db_train/s06/06.jpg
#   inflating: gt_db_train/s06/07.jpg
#   inflating: gt_db_train/s06/08.jpg
#   inflating: gt_db_train/s06/09.jpg
#   inflating: gt_db_train/s06/10.jpg
#    creating: gt_db_train/s07/
#   inflating: gt_db_train/s07/01.jpg
#   inflating: gt_db_train/s07/02.jpg
#   inflating: gt_db_train/s07/03.jpg
#   inflating: gt_db_train/s07/04.jpg
#   inflating: gt_db_train/s07/05.jpg
#   inflating: gt_db_train/s07/06.jpg
#   inflating: gt_db_train/s07/07.jpg
#   inflating: gt_db_train/s07/08.jpg
#   inflating: gt_db_train/s07/09.jpg
#   inflating: gt_db_train/s07/10.jpg
#    creating: gt_db_train/s08/
#   inflating: gt_db_train/s08/01.jpg
#   inflating: gt_db_train/s08/02.jpg
#   inflating: gt_db_train/s08/03.jpg
#   inflating: gt_db_train/s08/04.jpg
#   inflating: gt_db_train/s08/05.jpg
#   inflating: gt_db_train/s08/06.jpg
#   inflating: gt_db_train/s08/07.jpg
#   inflating: gt_db_train/s08/08.jpg
#   inflating: gt_db_train/s08/09.jpg
#   inflating: gt_db_train/s08/10.jpg
#    creating: gt_db_train/s09/
#   inflating: gt_db_train/s09/01.jpg
#   inflating: gt_db_train/s09/02.jpg
#   inflating: gt_db_train/s09/03.jpg
#   inflating: gt_db_train/s09/04.jpg
#   inflating: gt_db_train/s09/05.jpg
#   inflating: gt_db_train/s09/06.jpg
#   inflating: gt_db_train/s09/07.jpg
#   inflating: gt_db_train/s09/08.jpg
#   inflating: gt_db_train/s09/09.jpg
#   inflating: gt_db_train/s09/10.jpg
#    creating: gt_db_train/s10/
#   inflating: gt_db_train/s10/01.jpg
#   inflating: gt_db_train/s10/02.jpg
#   inflating: gt_db_train/s10/03.jpg
#   inflating: gt_db_train/s10/04.jpg
#   inflating: gt_db_train/s10/05.jpg
#   inflating: gt_db_train/s10/06.jpg
#   inflating: gt_db_train/s10/07.jpg
#   inflating: gt_db_train/s10/08.jpg
#   inflating: gt_db_train/s10/09.jpg
#   inflating: gt_db_train/s10/10.jpg
#    creating: gt_db_train/s11/
#   inflating: gt_db_train/s11/01.jpg
#   inflating: gt_db_train/s11/02.jpg
#   inflating: gt_db_train/s11/03.jpg
#   inflating: gt_db_train/s11/04.jpg
#   inflating: gt_db_train/s11/05.jpg
#   inflating: gt_db_train/s11/06.jpg
#   inflating: gt_db_train/s11/07.jpg
#   inflating: gt_db_train/s11/08.jpg
#   inflating: gt_db_train/s11/09.jpg
#   inflating: gt_db_train/s11/10.jpg
#    creating: gt_db_train/s12/
#   inflating: gt_db_train/s12/01.jpg
#   inflating: gt_db_train/s12/02.jpg
#   inflating: gt_db_train/s12/03.jpg
#   inflating: gt_db_train/s12/04.jpg
#   inflating: gt_db_train/s12/05.jpg
#   inflating: gt_db_train/s12/06.jpg
#   inflating: gt_db_train/s12/07.jpg
#   inflating: gt_db_train/s12/08.jpg
#   inflating: gt_db_train/s12/09.jpg
#   inflating: gt_db_train/s12/10.jpg
#    creating: gt_db_train/s13/
#   inflating: gt_db_train/s13/01.jpg
#   inflating: gt_db_train/s13/02.jpg
#   inflating: gt_db_train/s13/03.jpg
#   inflating: gt_db_train/s13/04.jpg
#   inflating: gt_db_train/s13/05.jpg
#   inflating: gt_db_train/s13/06.jpg
#   inflating: gt_db_train/s13/07.jpg
#   inflating: gt_db_train/s13/08.jpg
#   inflating: gt_db_train/s13/09.jpg
#   inflating: gt_db_train/s13/10.jpg
#    creating: gt_db_train/s14/
#   inflating: gt_db_train/s14/01.jpg
#   inflating: gt_db_train/s14/02.jpg
#   inflating: gt_db_train/s14/03.jpg
#   inflating: gt_db_train/s14/04.jpg
#   inflating: gt_db_train/s14/05.jpg
#   inflating: gt_db_train/s14/06.jpg
#   inflating: gt_db_train/s14/07.jpg
#   inflating: gt_db_train/s14/08.jpg
#   inflating: gt_db_train/s14/09.jpg
#   inflating: gt_db_train/s14/10.jpg
#    creating: gt_db_train/s15/
#   inflating: gt_db_train/s15/01.jpg
#   inflating: gt_db_train/s15/02.jpg
#   inflating: gt_db_train/s15/03.jpg
#   inflating: gt_db_train/s15/04.jpg
#   inflating: gt_db_train/s15/05.jpg
#   inflating: gt_db_train/s15/06.jpg
#   inflating: gt_db_train/s15/07.jpg
#   inflating: gt_db_train/s15/08.jpg
#   inflating: gt_db_train/s15/09.jpg
#   inflating: gt_db_train/s15/10.jpg
#    creating: gt_db_train/s16/
#   inflating: gt_db_train/s16/01.jpg
#   inflating: gt_db_train/s16/02.jpg
#   inflating: gt_db_train/s16/03.jpg
#   inflating: gt_db_train/s16/04.jpg
#   inflating: gt_db_train/s16/05.jpg
#   inflating: gt_db_train/s16/06.jpg
#   inflating: gt_db_train/s16/07.jpg
#   inflating: gt_db_train/s16/08.jpg
#   inflating: gt_db_train/s16/09.jpg
#   inflating: gt_db_train/s16/10.jpg
#    creating: gt_db_train/s17/
#   inflating: gt_db_train/s17/01.jpg
#   inflating: gt_db_train/s17/02.jpg
#   inflating: gt_db_train/s17/03.jpg
#   inflating: gt_db_train/s17/04.jpg
#   inflating: gt_db_train/s17/05.jpg
#   inflating: gt_db_train/s17/06.jpg
#   inflating: gt_db_train/s17/07.jpg
#   inflating: gt_db_train/s17/08.jpg
#   inflating: gt_db_train/s17/09.jpg
#   inflating: gt_db_train/s17/10.jpg
#    creating: gt_db_train/s18/
#   inflating: gt_db_train/s18/01.jpg
#   inflating: gt_db_train/s18/02.jpg
#   inflating: gt_db_train/s18/03.jpg
#   inflating: gt_db_train/s18/04.jpg
#   inflating: gt_db_train/s18/05.jpg
#   inflating: gt_db_train/s18/06.jpg
#   inflating: gt_db_train/s18/07.jpg
#   inflating: gt_db_train/s18/08.jpg
#   inflating: gt_db_train/s18/09.jpg
#   inflating: gt_db_train/s18/10.jpg
#    creating: gt_db_train/s19/
#   inflating: gt_db_train/s19/01.jpg
#   inflating: gt_db_train/s19/02.jpg
#   inflating: gt_db_train/s19/03.jpg
#   inflating: gt_db_train/s19/04.jpg
#   inflating: gt_db_train/s19/05.jpg
#   inflating: gt_db_train/s19/06.jpg
#   inflating: gt_db_train/s19/07.jpg
#   inflating: gt_db_train/s19/08.jpg
#   inflating: gt_db_train/s19/09.jpg
#   inflating: gt_db_train/s19/10.jpg
#    creating: gt_db_train/s20/
#   inflating: gt_db_train/s20/01.jpg
#   inflating: gt_db_train/s20/02.jpg
#   inflating: gt_db_train/s20/03.jpg
#   inflating: gt_db_train/s20/04.jpg
#   inflating: gt_db_train/s20/05.jpg
#   inflating: gt_db_train/s20/06.jpg
#   inflating: gt_db_train/s20/07.jpg
#   inflating: gt_db_train/s20/08.jpg
#   inflating: gt_db_train/s20/09.jpg
#   inflating: gt_db_train/s20/10.jpg
#    creating: gt_db_val/
#    creating: gt_db_val/s01/
#   inflating: gt_db_val/s01/11.jpg
#   inflating: gt_db_val/s01/12.jpg
#   inflating: gt_db_val/s01/13.jpg
#   inflating: gt_db_val/s01/14.jpg
#   inflating: gt_db_val/s01/15.jpg
#    creating: gt_db_val/s02/
#   inflating: gt_db_val/s02/11.jpg
#   inflating: gt_db_val/s02/12.jpg
#   inflating: gt_db_val/s02/13.jpg
#   inflating: gt_db_val/s02/14.jpg
#   inflating: gt_db_val/s02/15.jpg
#    creating: gt_db_val/s03/
#   inflating: gt_db_val/s03/11.jpg
#   inflating: gt_db_val/s03/12.jpg
#   inflating: gt_db_val/s03/13.jpg
#   inflating: gt_db_val/s03/14.jpg
#   inflating: gt_db_val/s03/15.jpg
#    creating: gt_db_val/s04/
#   inflating: gt_db_val/s04/11.jpg
#   inflating: gt_db_val/s04/12.jpg
#   inflating: gt_db_val/s04/13.jpg
#   inflating: gt_db_val/s04/14.jpg
#   inflating: gt_db_val/s04/15.jpg
#    creating: gt_db_val/s05/
#   inflating: gt_db_val/s05/11.jpg
#   inflating: gt_db_val/s05/12.jpg
#   inflating: gt_db_val/s05/13.jpg
#   inflating: gt_db_val/s05/14.jpg
#   inflating: gt_db_val/s05/15.jpg
#    creating: gt_db_val/s06/
#   inflating: gt_db_val/s06/11.jpg
#   inflating: gt_db_val/s06/12.jpg
#   inflating: gt_db_val/s06/13.jpg
#   inflating: gt_db_val/s06/14.jpg
#   inflating: gt_db_val/s06/15.jpg
#    creating: gt_db_val/s07/
#   inflating: gt_db_val/s07/11.jpg
#   inflating: gt_db_val/s07/12.jpg
#   inflating: gt_db_val/s07/13.jpg
#   inflating: gt_db_val/s07/14.jpg
#   inflating: gt_db_val/s07/15.jpg
#    creating: gt_db_val/s08/
#   inflating: gt_db_val/s08/11.jpg
#   inflating: gt_db_val/s08/12.jpg
#   inflating: gt_db_val/s08/13.jpg
#   inflating: gt_db_val/s08/14.jpg
#   inflating: gt_db_val/s08/15.jpg
#    creating: gt_db_val/s09/
#   inflating: gt_db_val/s09/11.jpg
#   inflating: gt_db_val/s09/12.jpg
#   inflating: gt_db_val/s09/13.jpg
#   inflating: gt_db_val/s09/14.jpg
#   inflating: gt_db_val/s09/15.jpg
#    creating: gt_db_val/s10/
#   inflating: gt_db_val/s10/11.jpg
#   inflating: gt_db_val/s10/12.jpg
#   inflating: gt_db_val/s10/13.jpg
#   inflating: gt_db_val/s10/14.jpg
#   inflating: gt_db_val/s10/15.jpg
#    creating: gt_db_val/s11/
#   inflating: gt_db_val/s11/11.jpg
#   inflating: gt_db_val/s11/12.jpg
#   inflating: gt_db_val/s11/13.jpg
#   inflating: gt_db_val/s11/14.jpg
#   inflating: gt_db_val/s11/15.jpg
#    creating: gt_db_val/s12/
#   inflating: gt_db_val/s12/11.jpg
#   inflating: gt_db_val/s12/12.jpg
#   inflating: gt_db_val/s12/13.jpg
#   inflating: gt_db_val/s12/14.jpg
#   inflating: gt_db_val/s12/15.jpg
#    creating: gt_db_val/s13/
#   inflating: gt_db_val/s13/11.jpg
#   inflating: gt_db_val/s13/12.jpg
#   inflating: gt_db_val/s13/13.jpg
#   inflating: gt_db_val/s13/14.jpg
#   inflating: gt_db_val/s13/15.jpg
#    creating: gt_db_val/s14/
#   inflating: gt_db_val/s14/11.jpg
#   inflating: gt_db_val/s14/12.jpg
#   inflating: gt_db_val/s14/13.jpg
#   inflating: gt_db_val/s14/14.jpg
#   inflating: gt_db_val/s14/15.jpg
#    creating: gt_db_val/s15/
#   inflating: gt_db_val/s15/11.jpg
#   inflating: gt_db_val/s15/12.jpg
#   inflating: gt_db_val/s15/13.jpg
#   inflating: gt_db_val/s15/14.jpg
#   inflating: gt_db_val/s15/15.jpg
#    creating: gt_db_val/s16/
#   inflating: gt_db_val/s16/11.jpg
#   inflating: gt_db_val/s16/12.jpg
#   inflating: gt_db_val/s16/13.jpg
#   inflating: gt_db_val/s16/14.jpg
#   inflating: gt_db_val/s16/15.jpg
#    creating: gt_db_val/s17/
#   inflating: gt_db_val/s17/11.jpg
#   inflating: gt_db_val/s17/12.jpg
#   inflating: gt_db_val/s17/13.jpg
#   inflating: gt_db_val/s17/14.jpg
#   inflating: gt_db_val/s17/15.jpg
#    creating: gt_db_val/s18/
#   inflating: gt_db_val/s18/11.jpg
#   inflating: gt_db_val/s18/12.jpg
#   inflating: gt_db_val/s18/13.jpg
#   inflating: gt_db_val/s18/14.jpg
#   inflating: gt_db_val/s18/15.jpg
#    creating: gt_db_val/s19/
#   inflating: gt_db_val/s19/11.jpg
#   inflating: gt_db_val/s19/12.jpg
#   inflating: gt_db_val/s19/13.jpg
#   inflating: gt_db_val/s19/14.jpg
#   inflating: gt_db_val/s19/15.jpg
#    creating: gt_db_val/s20/
#   inflating: gt_db_val/s20/11.jpg
#   inflating: gt_db_val/s20/12.jpg
#   inflating: gt_db_val/s20/13.jpg
#   inflating: gt_db_val/s20/14.jpg
#   inflating: gt_db_val/s20/15.jpg

# %%
# %cd /content/drive/MyDrive/dataset
# Out:
# /content/drive/MyDrive/dataset

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
# Create a data generator
from keras.preprocessing.image import ImageDataGenerator

#Assignment7.1 part1
img_rows, img_cols = 100, 100
input_shape = (img_rows, img_cols, 3)
num_classes = 20
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory('/content/drive/MyDrive/dataset/gt_db_train',target_size=(img_rows,img_cols),batch_size=10,class_mode='categorical', shuffle=True)
step_size_train = train_generator.n/train_generator.batch_size
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_directory('/content/drive/MyDrive/dataset/gt_db_val',target_size=(img_rows,img_cols),batch_size=10,class_mode='categorical', shuffle=True)
step_size_val = val_generator.n/val_generator.batch_size
# Out:
# Found 200 images belonging to 20 classes.
# Found 100 images belonging to 20 classes.

# %%
#Assignment7,1 part2
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 64)       0
#  )
#
#  flatten (Flatten)           (None, 147456)            0
#
#  dense (Dense)               (None, 128)               18874496
#
#  dense_1 (Dense)             (None, 20)                2580
#
# =================================================================
# Total params: 18,896,468
# Trainable params: 18,896,468
# Non-trainable params: 0
# _________________________________________________________________

# %%
##Assignment7,1 part3
from tensorflow.keras.optimizers import SGD, Adam

adam = Adam(lr=0.0003)
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=adam,
              metrics=['accuracy'])

history = model.fit_generator(generator=train_generator,
                   steps_per_epoch=step_size_train,epochs=10,
                   validation_data=val_generator,
                   validation_steps=step_size_val)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# <ipython-input-3-19bd37ccd502>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_generator,
# Epoch 1/10
# 20/20 [==============================] - 174s 8s/step - loss: 3.1980 - accuracy: 0.1950 - val_loss: 2.0065 - val_accuracy: 0.6400
# Epoch 2/10
# 20/20 [==============================] - 3s 160ms/step - loss: 1.4294 - accuracy: 0.7250 - val_loss: 0.6980 - val_accuracy: 0.8700
# Epoch 3/10
# 20/20 [==============================] - 3s 159ms/step - loss: 0.3951 - accuracy: 0.9500 - val_loss: 0.2634 - val_accuracy: 0.9400
# Epoch 4/10
# 20/20 [==============================] - 10s 505ms/step - loss: 0.1413 - accuracy: 0.9650 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 5/10
# 20/20 [==============================] - 9s 433ms/step - loss: 0.0524 - accuracy: 0.9950 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 6/10
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 7/10
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 8/10
# 20/20 [==============================] - 3s 164ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 9/10
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 10/10
# 20/20 [==============================] - 3s 161ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000

# %%
##Assignment7,1 part4
import matplotlib
import matplotlib.pyplot as plt
# Plot training accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Acuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validate'], loc='upper left')
plt.savefig('Accuracy.png')
plt.show()

# Plot training loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validate'], loc='upper left')
plt.savefig('Loss.png')
plt.show()
